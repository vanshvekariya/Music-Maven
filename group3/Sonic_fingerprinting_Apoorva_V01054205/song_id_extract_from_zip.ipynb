# %%
import zipfile
import os

def extract_specific_files(zip_path, files_to_extract, output_dir, password):

    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    pwd = password.encode('utf-8')

    with zipfile.ZipFile(zip_path, 'r') as z:

        all_files = set(z.namelist())

        files_found = [f for f in files_to_extract if f in all_files]

        print(f"Found {len(files_found)} files to extract")

        for f in files_found:
            z.extract(f, path=output_dir, pwd=pwd)

        print("Extraction complete")


zip_file_path = r"C:\SID\Apoorva\Project\Music Maven Project\music4all.zip"
output_folder = r"C:\SID\Apoorva\Project\Music Maven Project\Output_audio_files"
zip_password = "ifjlryvm2019"
txt_file_path = r"C:\SID\Apoorva\Project\Music Maven Project\mp3_list.txt"


files_to_extract = []

with open(txt_file_path, "r") as f:
    for line in f:
        filename = line.strip()
        if filename:
            files_to_extract.append(f"music4all/audios/{filename}")

extract_specific_files(zip_file_path, files_to_extract, output_folder, zip_password)

# %%
import zipfile

zip_file_path = r"C:\SID\Apoorva\Project\Music Maven Project\music4all.zip"

with zipfile.ZipFile(zip_file_path, 'r') as z:
    for name in z.namelist()[:20]:
        print(name)

# %%
import zipfile
import os

def extract_specific_files(zip_path, files_to_extract, output_dir, password):

    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    pwd = password.encode('utf-8')

    with zipfile.ZipFile(zip_path, 'r') as z:

        all_files = set(z.namelist())

        files_found = [f for f in files_to_extract if f in all_files]

        print(f"Found {len(files_found)} files to extract")

        for f in files_found:
            z.extract(f, path=output_dir, pwd=pwd)

        print("Extraction complete")


zip_file_path = r"C:\SID\Apoorva\Project\Music Maven Project\music4all.zip"
output_folder = r"C:\SID\Apoorva\Project\Music Maven Project\Output_audio_files"
zip_password = "ifjlryvm2019"
txt_file_path = r"C:\SID\Apoorva\Project\Music Maven Project\mp3_list.txt"


files_to_extract = []

with open(txt_file_path, "r") as f:
    for line in f:
        filename = line.strip()
        if filename:
            files_to_extract.append(f"music4all/audios/{filename}")

extract_specific_files(zip_file_path, files_to_extract, output_folder, zip_password)
# Out:
# Found 10000 files to extract
# Extraction complete
